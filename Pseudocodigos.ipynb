# %% [markdown]
# 1. Ejercicio 1
# ### 📌 Pseudocódigo: Suma con truncamiento a cifras significativas
#
# ```plaintext
# Función Truncar_Significativas(x, cifras = 3):
#     Si x es igual a 0:
#         Retornar 0.0
#     Si no:
#         orden ← parte_entera( log10( valor_absoluto(x) ) )
#         factor ← 10 elevado a (cifras - 1 - orden)
#         resultado ← truncar(x * factor) / factor
#         Retornar resultado
# FinFunción
#
# // Suma de mayor a menor: i desde 1 hasta 10
# suma_mayor_a_menor ← 0.0
# Para i desde 1 hasta 10 hacer:
#     term ← 1 / (i^2)
#     suma_mayor_a_menor ← Truncar_Significativas(suma_mayor_a_menor + Truncar_Significativas(term))
# FinPara
#
# // Suma de menor a mayor: i desde 10 hasta 1
# suma_menor_a_mayor ← 0.0
# Para i desde 10 hasta 1 con paso -1 hacer:
#     term ← 1 / (i^2)
#     suma_menor_a_mayor ← Truncar_Significativas(suma_menor_a_mayor + Truncar_Significativas(term))
# FinPara
#
# Mostrar "Parte a:"
# Mostrar "  Suma de mayor a menor: ", suma_mayor_a_menor
# Mostrar "  Suma de menor a mayor: ", suma_menor_a_mayor

# %% [markdown]
# ## Serie de Maclaurin
# ### 📌 Pseudocódigo: Aproximación de π usando la serie de Maclaurin de arctan(1)
#
# ```plaintext
# Función Maclaurin_Arctan_Aprox(n):
#     suma ← 0
#     Para i desde 1 hasta n hacer:
#         término ← (-1)^(i + 1) / (2 * i - 1)
#         suma ← suma + término
#     FinPara
#     Retornar suma
# FinFunción
#
# n_términos ← 0
# precisión ← 10^(-3)
# diferencia ← 1  // Inicializar con un valor mayor a la precisión
#
# Mientras diferencia ≥ precisión hacer:
#     n_términos ← n_términos + 1
#     aproximación_actual ← 4 * Maclaurin_Arctan_Aprox(n_términos)
#     diferencia ← valor_absoluto(aproximación_actual - π)
# FinMientras
#
# Mostrar "Número de términos necesarios para alcanzar la precisión de 10^-3: ", n_términos

# %% [markdown]
# ##### b. El lenguaje de programación C++ requiere que el valor de $(\pi)$ se encuentre dentro de $(10^{-6})$. ¿Cuántos términos de la serie se necesitarían sumar para obtener este grado de precisión?
# ###  Pseudocódigo: Aproximación de π con precisión deseada usando la serie de Leibniz
#
# ```plaintext
# Función Calcular_π(precisión_deseada):
#     tolerancia ← 0.5 × 10^(-precisión_deseada)
#     suma ← 0.0
#     n ← 0
#     signo ← 1
#
#     Repetir:
#         término ← signo / (2 × n + 1)
#         suma ← suma + término
#         aproximación ← 4 × suma
#         error ← valor_absoluto(aproximación - π)
#
#         Si error < tolerancia:
#             Salir del ciclo
#
#         signo ← signo × (-1)
#         n ← n + 1
#     Hasta que el error sea menor que la tolerancia
#
#     Retornar n + 1, aproximación
# FinFunción
#
# // Llamada principal
# precisión_deseada ← 6
# (n_terminos, aproximación) ← Calcular_π(precisión_deseada)
# Mostrar "Número de términos necesarios para alcanzar la precisión de 10^-6: ", n_terminos

# %% [markdown]
# ### 3. Aproximación de $\pi$ mediante otra identidad
# ### Pseudocódigo: Aproximación de π usando la identidad de Machin y series de Maclaurin
#
# ```plaintext
# Función Maclaurin_Arctan(x, términos):
#     suma ← 0
#     Para i desde 0 hasta términos - 1 hacer:
#         término ← (-1)^i * (x^(2 * i + 1)) / (2 * i + 1)
#         suma ← suma + término
#     FinPara
#     Retornar suma
# FinFunción
#
# Función Calcular_π_Desde_Identidad(términos):
#     pi_aprox ← 4 * (4 * Maclaurin_Arctan(1 / 5, términos) - Maclaurin_Arctan(1 / 239, términos))
#     Retornar pi_aprox
# FinFunción
#
# umbral_de_precisión ← 10^(-3)
# términos_usados ← 0
# error_aproximación_π ← 1
#
# Mientras error_aproximación_π ≥ umbral_de_precisión hacer:
#     términos_usados ← términos_usados + 1
#     valor_actual_π ← Calcular_π_Desde_Identidad(términos_usados)
#     error_aproximación_π ← valor_absoluto(valor_actual_π - π)
# FinMientras
#
# Mostrar "Número de términos necesarios para obtener precisión de 10^-3: ", términos_usados

# %% [markdown]
# ### 🧮 Escriba un algoritmo para sumar la serie finita:
# ```plaintext
# x ← [1, 2, 3, 4, 5]
# suma ← 0
#
# Para i desde longitud(x) - 1 hasta 0 con paso -1 hacer:
#     suma ← suma + x[i]
#     Mostrar "La suma en orden inverso es: ", suma
# FinPara

# %% [markdown]
# ### Construya un algoritmo con entrada 𝑎, 𝑏, 𝑐 c y salida 𝑥1, 𝑥2 que calcule las raíces 𝑥1 y 𝑥2
# ```plaintext
# Leer a
# Leer b
# Leer c
#
# Si a == 0 entonces:
#     Mostrar "No es una ecuación cuadrática"
# Sino:
#     D ← b^2 - 4ac  // Discriminante
#
#     Si D < 0 entonces:
#         Mostrar "No tiene solución real"
#
#     Sino si D == 0 entonces:
#         x ← -b / (2a)
#         Mostrar "La solución es:", x
#
#     Sino:
#         x1 ← (-b + raíz(D)) / (2a)
#         x2 ← (-b - raíz(D)) / (2a)
#         Mostrar "Las soluciones son:", x1, "y", x2

# %% [markdown]
# ###  Escriba y ejecute un algoritmo que determine el número de términos necesarios en el lado izquierdo de la ecuación de tal forma que el lado izquierdo difiera del lado derecho en menos de 10−6
# ```plaintext
# x ← 0.25
# tolerancia ← 10^(-6)
#
# // Calcular lado derecho de la expresión
# lado_derecho ← (1 + 2·x) / (1 + x + x²)
#
# suma ← 0.0
# n ← 1
#
# Mientras valor_absoluto(suma - lado_derecho) ≥ tolerancia hacer:
#     a ← 2^(n - 1) × x^(2^(n - 1) - 1)
#     b ← 2^n × x^(2^n - 1)
#     numerador ← a - b
#     denominador ← 1 - x^(2^(n - 1)) + x^(2^n)
#     término ← numerador / denominador
#
#     suma ← suma + término
#     n ← n + 1
# FinMientras
#
# Mostrar "Número de términos necesarios: ", n - 1
# Mostrar "Suma parcial: ", suma
# Mostrar "Valor lado derecho: ", lado_derecho
